# %%
from github import Github

# First create a Github instance:

# using username and password
username="gs9783@gmail.com"
password="samba1234"
g = Github(username, password)
for repo in g.get_user().get_repos():
    print(repo.name)
# Out:
# batch44_repo0
# khyaathirepo1
# khyaathirepo2
# python_repo
# repo410
# repocreatedbyAPI
# repo_api
# batch44
# batch44_auto
# batch44_repo2
# batch44_repo1
# newrepo
# repo411
# batch44
# batch44_1
# django
# python
# r1234
# repo1
# repo123

# %%
dir(g)
# Out:
# ['FIX_REPO_GET_GIT_REF',
#  '_Github__get_FIX_REPO_GET_GIT_REF',
#  '_Github__get_per_page',
#  '_Github__requester',
#  '_Github__set_FIX_REPO_GET_GIT_REF',
#  '_Github__set_per_page',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'create_from_raw_data',
#  'dump',
#  'get_api_status',
#  'get_api_status_messages',
#  'get_emojis',
#  'get_gist',
#  'get_gists',
#  'get_gitignore_template',
#  'get_gitignore_templates',
#  'get_hook',
#  'get_hooks',
#  'get_installation',
#  'get_last_api_status_message',
#  'get_organization',
#  'get_rate_limit',
#  'get_repo',
#  'get_repos',
#  'get_user',
#  'get_users',
#  'legacy_search_repos',
#  'legacy_search_user_by_email',
#  'legacy_search_users',
#  'load',
#  'oauth_scopes',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# UnknownObjectException                    Traceback (most recent call last)
# <ipython-input-5-39e162bef79a> in <module>()
# ----> 1 for org in g.get_organization("uday1834"):
#       2     print org
#
# /home/khyaathi-python/anaconda2/lib/python2.7/site-packages/github/MainClass.pyc in get_organization(self, login)
#     196         headers, data = self.__requester.requestJsonAndCheck(
#     197             "GET",
# --> 198             "/orgs/" + login
#     199         )
#     200         return github.Organization.Organization(self.__requester, headers, data, completed=True)
#
# /home/khyaathi-python/anaconda2/lib/python2.7/site-packages/github/Requester.pyc in requestJsonAndCheck(self, verb, url, parameters, headers, input, cnx)
#     170
#     171     def requestJsonAndCheck(self, verb, url, parameters=None, headers=None, input=None, cnx=None):
# ...

# %%
user = g.get_user()

# %%
dir(user)
# Out:
# ['CHECK_AFTER_INIT_FLAG',
#  '_CompletableGithubObject__complete',
#  '_CompletableGithubObject__completed',
#  '_GithubObject__makeSimpleAttribute',
#  '_GithubObject__makeSimpleListAttribute',
#  '_GithubObject__makeTransformedAttribute',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_avatar_url',
#  '_bio',
#  '_blog',
#  '_collaborators',
#  '_company',
#  '_completeIfNeeded',
#  '_completeIfNotSet',
#  '_created_at',
#  '_disk_usage',
#  '_email',
#  '_events_url',
#  '_followers',
#  '_followers_url',
#  '_following',
#  '_following_url',
#  '_gists_url',
#  '_gravatar_id',
#  '_headers',
#  '_hireable',
#  '_html_url',
#  '_id',
#  '_initAttributes',
#  '_location',
#  '_login',
# ...

# %%
for org in user.get_orgs():
    print org
# Out:
# Organization(name=None, id=34699715)
# Organization(name=None, id=34699732)
# Organization(name=None, id=37465038)

# %%
dir(org)
# Out:
# ['CHECK_AFTER_INIT_FLAG',
#  '_CompletableGithubObject__complete',
#  '_CompletableGithubObject__completed',
#  '_GithubObject__makeSimpleAttribute',
#  '_GithubObject__makeSimpleListAttribute',
#  '_GithubObject__makeTransformedAttribute',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_avatar_url',
#  '_billing_email',
#  '_blog',
#  '_collaborators',
#  '_company',
#  '_completeIfNeeded',
#  '_completeIfNotSet',
#  '_created_at',
#  '_disk_usage',
#  '_email',
#  '_events_url',
#  '_followers',
#  '_following',
#  '_gravatar_id',
#  '_headers',
#  '_html_url',
#  '_id',
#  '_initAttributes',
#  '_location',
#  '_login',
#  '_makeBoolAttribute',
#  '_makeClassAttribute',
# ...

# %%
org.__dict__
# Out:
# {'_CompletableGithubObject__completed': True,
#  '_avatar_url': <github.GithubObject._ValuedAttribute instance at 0x7f842fb573f8>,
#  '_billing_email': <github.GithubObject._ValuedAttribute instance at 0x7f842fb57908>,
#  '_blog': NotSet,
#  '_collaborators': <github.GithubObject._ValuedAttribute instance at 0x7f842fb573b0>,
#  '_company': NotSet,
#  '_created_at': <github.GithubObject._ValuedAttribute instance at 0x7f842fb57638>,
#  '_disk_usage': <github.GithubObject._ValuedAttribute instance at 0x7f842fb57680>,
#  '_email': NotSet,
#  '_events_url': <github.GithubObject._ValuedAttribute instance at 0x7f842fb574d0>,
#  '_followers': <github.GithubObject._ValuedAttribute instance at 0x7f842fb57950>,
#  '_following': <github.GithubObject._ValuedAttribute instance at 0x7f842fb57488>,
#  '_gravatar_id': NotSet,
#  '_headers': {'access-control-allow-origin': '*',
# ...

# %%
org.url
# Out:
# u'https://api.github.com/orgs/khyaathiinstitute'

# %%
org.create_repo("batch46")
# Out:
# Repository(full_name="khyaathiinstitute/batch46")

# %%
# consider that it does not contains the python module
# do you have API to connect your device: yes
import requests
#resp=requests.get(url,auth(),params={})
#resp=requests.post(url,auth(),json/data={})
#resp=requests.put(url/id,auth(),data/json={})
#resp=requests.delete(url/id,auth(),)

# %%
resp=requests.get("https://api.github.com/users/octocat/orgs",
                  auth=(username, password))

# %%
resp.status_code
# Out:
# 200

# %%
resp.reason
# Out:
# 'OK'

# %%
resp.json()
# Out:
# []

# %%
resp=requests.get("https://api.github.com/orgs/octokit/repos",
                  auth=(username, password))
resp.status_code
# Out:
# 200

# %%
resp.json()
# Out:
# [{u'archive_url': u'https://api.github.com/repos/octokit/octokit.rb/{archive_format}{/ref}',
#   u'archived': False,
#   u'assignees_url': u'https://api.github.com/repos/octokit/octokit.rb/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/octokit/octokit.rb/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/octokit/octokit.rb/branches{/branch}',
#   u'clone_url': u'https://github.com/octokit/octokit.rb.git',
#   u'collaborators_url': u'https://api.github.com/repos/octokit/octokit.rb/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/octokit/octokit.rb/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/octokit/octokit.rb/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/octokit/octokit.rb/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/octokit/octokit.rb/contents/{+path}',
# ...

# %%
resp=requests.get("https://api.github.com/orgs/tcloud123/repos",
                  auth=(username, password))
resp.status_code
# Out:
# 200

# %%
resp.json()
# Out:
# [{u'archive_url': u'https://api.github.com/repos/tcloud123/repo411/{archive_format}{/ref}',
#   u'archived': False,
#   u'assignees_url': u'https://api.github.com/repos/tcloud123/repo411/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/tcloud123/repo411/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/tcloud123/repo411/branches{/branch}',
#   u'clone_url': u'https://github.com/tcloud123/repo411.git',
#   u'collaborators_url': u'https://api.github.com/repos/tcloud123/repo411/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/tcloud123/repo411/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/tcloud123/repo411/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/tcloud123/repo411/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/tcloud123/repo411/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/tcloud123/repo411/contributors',
# ...

# %%
resp=requests.post("https://api.github.com/orgs/tcloud123/repos/",
                  auth=(username, password),json={"name":"batch46"})
resp.status_code
# Out:
# 404

# %%
# consider that it does not contains the python module
# do you have API to connect your device: no
# does your machine running with default serivces like ssh,scp: yes

# %%
import os

# %%
os.system("mkdir f1")
# Out:
# 0

# %%
os.system("rm -r f1")
# Out:
# 0

# %%
os.system("ps -aux")
# Out:
# 0

# %%
import subprocess

# %%
resp = subprocess.check_output(["ps","-aux"])
print resp
# Out:
# USER       PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND
# root         1  0.0  0.1 137384  7320 ?        Ss   02:57   0:01 /sbin/init splash
# root         2  0.0  0.0      0     0 ?        S    02:57   0:00 [kthreadd]
# root         3  0.0  0.0      0     0 ?        S    02:57   0:00 [ksoftirqd/0]
# root         5  0.0  0.0      0     0 ?        S<   02:57   0:00 [kworker/0:0H]
# root         7  0.0  0.0      0     0 ?        S    02:57   0:03 [rcu_sched]
# root         8  0.0  0.0      0     0 ?        S    02:57   0:00 [rcu_bh]
# root         9  0.0  0.0      0     0 ?        S    02:57   0:00 [migration/0]
# root        10  0.0  0.0      0     0 ?        S<   02:57   0:00 [lru-add-drain]
# root        11  0.0  0.0      0     0 ?        S    02:57   0:00 [watchdog/0]
# root        12  0.0  0.0      0     0 ?        S    02:57   0:00 [cpuhp/0]
# root        13  0.0  0.0      0     0 ?        S    02:57   0:00 [kdevtmpfs]
# ...

# %%
import paramiko as pmk

# %%
ssh=pmk.SSHClient()

# %%
import paramiko as pmk
ssh = pmk.SSHClient()
ssh.set_missing_host_key_policy(pmk.AutoAddPolicy())
username="khyaathi-python"
password="pythonkhyaathi"
ssh.connect("localhost",username=username,password=password)
