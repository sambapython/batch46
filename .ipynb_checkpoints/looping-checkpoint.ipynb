# %%
# while for
print "program started"
i=0
if i<3:
    print i
    i=i+1
print "othere statements in program"
print "program ended"
# Out:
# program started
# 0
# othere statements in program
# program ended

# %%
# while for
print "program started"
i=0
while i<3:
    print i
    i=i+1
print "othere statements in program"
print "program ended"
# Out:
# program started
# 0
# 1
# 2
# othere statements in program
# program ended

# %%
# while for
print "program started"
i=0
while i<-3:
    print i
    i=i+1
print "othere statements in program"
print "program ended"
# Out:
# program started
# othere statements in program
# program ended

# %%
# while for
print "program started"
i=0
while i<-3:
    print "iteration strted"
    print i
    i=i+1
    print "iteration ended"
print "othere statements in program"
print "program ended"
# Out:
# program started
# othere statements in program
# program ended

# %%
# while for
print "program started"
i=0
while i<3:
    print "iteration strted"
    print i
    i=i+1
    print "iteration ended"
print "othere statements in program"
print "program ended"
# Out:
# program started
# iteration strted
# 0
# iteration ended
# iteration strted
# 1
# iteration ended
# iteration strted
# 2
# iteration ended
# othere statements in program
# program ended

# %%
# while for
print "program started"
for i in "python":
    print i
print "othere statements in program"
print "program ended"
# Out:
# program started
# p
# y
# t
# h
# o
# n
# othere statements in program
# program ended

# %%
# while for
print "program started"
s="python"
i=0
while i<len(s):
    print s[i]
    i=i+1
print "othere statements in program"
print "program ended"
# Out:
# program started
# p
# y
# t
# h
# o
# n
# othere statements in program
# program ended

# %%
# while for
print "program started"
for i in ["Anil","pavan","naveen","ashok","praveen"]:
    print i
print "othere statements in program"
print "program ended"
# Out:
# program started
# Anil
# pavan
# naveen
# ashok
# praveen
# othere statements in program
# program ended

# %%
# while for
print "program started"
for i in ("Anil","pavan","naveen","ashok","praveen"):
    print i
print "othere statements in program"
print "program ended"
# Out:
# program started
# Anil
# pavan
# naveen
# ashok
# praveen
# othere statements in program
# program ended

# %%
# while for
print "program started"
for i in {"name":"jay","age":1.3,"height":3}:
    print i
print "othere statements in program"
print "program ended"
# Out:
# program started
# age
# name
# height
# othere statements in program
# program ended

# %%
# while for
print "program started"
d={"name":"jay","age":1.3,"height":3}
for i in d:
    print i,d[i]
print "othere statements in program"
print "program ended"
# Out:
# program started
# age 1.3
# name jay
# height 3
# othere statements in program
# program ended

# %%
# while for
print "program started"
for i in {"Anil","pavan","naveen","ashok","praveen"}:
    print i
print "othere statements in program"
print "program ended"
# Out:
# program started
# pavan
# Anil
# ashok
# praveen
# naveen
# othere statements in program
# program ended

# %%
# while for
print "program started"
for i in 1000:
    print i
print "othere statements in program"
print "program ended"
# Out:
# program started
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-3587035296f6> in <module>()
#       1 # while for
#       2 print "program started"
# ----> 3 for i in 1000:
#       4     print i
#       5 print "othere statements in program"
#
# TypeError: 'int' object is not iterable

# %%
# while for
print "program started"
for i in 1000.23456:
    print i
print "othere statements in program"
print "program ended"
# Out:
# program started
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-cdd76dc1bc48> in <module>()
#       1 # while for
#       2 print "program started"
# ----> 3 for i in 1000.23456:
#       4     print i
#       5 print "othere statements in program"
#
# TypeError: 'float' object is not iterable

# %%
# while for
print "program started"
for i in 1000+2j:
    print i
print "othere statements in program"
print "program ended"
# Out:
# program started
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-59530fa7ee7e> in <module>()
#       1 # while for
#       2 print "program started"
# ----> 3 for i in 1000+2j:
#       4     print i
#       5 print "othere statements in program"
#
# TypeError: 'complex' object is not iterable

# %%
# while for
print "program started"
for i in True:
    print i
print "othere statements in program"
print "program ended"
# Out:
# program started
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-a2a9da60acea> in <module>()
#       1 # while for
#       2 print "program started"
# ----> 3 for i in True:
#       4     print i
#       5 print "othere statements in program"
#
# TypeError: 'bool' object is not iterable

# %%
# while for
print "program started"
for i in None:
    print i
print "othere statements in program"
print "program ended"
# Out:
# program started
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-0f36d782130b> in <module>()
#       1 # while for
#       2 print "program started"
# ----> 3 for i in None:
#       4     print i
#       5 print "othere statements in program"
#
# TypeError: 'NoneType' object is not iterable

# %%
# while for
print "program started"
for i in "10000":
    print i
print "othere statements in program"
print "program ended"
# Out:
# program started
# 1
# 0
# 0
# 0
# 0
# othere statements in program
# program ended

# %%
# while for
print "program started"
for i in {"Anil","pavan","naveen","ashok","praveen"}:
    print "iteration started"
    print i
    print "iteration ended"
    
print "othere statements in program"
print "program ended"
# Out:
# program started
# iteration started
# pavan
# iteration ended
# iteration started
# Anil
# iteration ended
# iteration started
# ashok
# iteration ended
# iteration started
# praveen
# iteration ended
# iteration started
# naveen
# iteration ended
# othere statements in program
# program ended

# %%
# while for
print "program started"
s=raw_input("Enter a value:")
for i in s:
    print i
    
print "othere statements in program"
print "program ended"
# Out:
# program started
# Enter a value:abcd
# a
# b
# c
# d
# othere statements in program
# program ended

# %%
# while for
print "program started"
s=raw_input("Enter a value:")
for i in s:
    print i
    
print "othere statements in program"
print "program ended"
#<space>
# Out:
# program started
# Enter a value:a b c d
# a
#
# b
#
# c
#
# d
# othere statements in program
# program ended

# %%
# while for
#<space># 
print "program started"
s=raw_input("Enter a value:")
for i in s:
    if i==" ":
        print "<SPACE>"
    else:
        print i
print "othere statements in program"
print "program ended"
# Out:
# program started
# Enter a value:abcd
# a
# b
# c
# d
# othere statements in program
# program ended

# %%
# while for
#<space># 
print "program started"
s=raw_input("Enter a value:")
for i in s:
    if i==" ":
        print "<SPACE>"
    else:
        print i
    
print "othere statements in program"
print "program ended"
# Out:
# program started
# Enter a value:a b c
# a
# <SPACE>
# b
# <SPACE>
# c
# othere statements in program
# program ended

# %%
# while for=
print "program started"
s=raw_input("Enter a value:")
for i in s:
    if i==" ":
        pass
    else:
        print i
    
print "othere statements in program"
print "program ended"
# Out:
# program started
# Enter a value:abcd
# a
# b
# c
# d
# othere statements in program
# program ended

# %%
# while for=
print "program started"
s=raw_input("Enter a value:")
for i in s:
    if i==" ":
        pass
    else:
        print i
    
print "othere statements in program"
print "program ended"
# Out:
# program started
# Enter a value:a b c d
# a
# b
# c
# d
# othere statements in program
# program ended

# %%
# while for=
print "program started"
s=raw_input("Enter a value:")
for i in s:
    if i==" ":
        break
    else:
        print i
    
print "othere statements in program"
print "program ended"
# Out:
# program started
# Enter a value:abcd
# a
# b
# c
# d
# othere statements in program
# program ended

# %%
# while for=
print "program started"
s=raw_input("Enter a value:")
for i in s:
    if i==" ":
        break
    else:
        print i
    
print "othere statements in program"
print "program ended"
# Out:
# program started
# Enter a value:a b c d
# a
# othere statements in program
# program ended

# %%
# while for=
print "program started"
s=raw_input("Enter a value:")
for i in s:
    print "iteration started for: %s"%i
    if i==" ":
        break
        print "<SPACE>"
    else:
        print i
    print "iteration ended for: %s"%i
    
print "othere statements in program"
print "program ended"
# Out:
# program started
# Enter a value:a b c
# iteration started for: a
# a
# iteration ended for: a
# iteration started for:
# othere statements in program
# program ended

# %%
# while for=
print "program started"
s=raw_input("Enter a value:")
for i in s:
    print "iteration started for: %s"%i
    if i==" ":
        print "<SPACE>"
        break
    else:
        print i
    print "iteration ended for: %s"%i
    
print "othere statements in program"
print "program ended"
# Out:
# program started
# Enter a value:a b c d
# iteration started for: a
# a
# iteration ended for: a
# iteration started for:
# <SPACE>
# othere statements in program
# program ended

# %%
# while for=
print "program started"
s=raw_input("Enter a value:")
for i in s:
    print "iteration started for: %s"%i
    if i==" ":
        print "<SPACE>"
        break
    else:
        print i
    print "iteration ended for: %s"%i
    
print "othere statements in program"
print "program ended"
# Out:
# program started
# Enter a value:abcd
# iteration started for: a
# a
# iteration ended for: a
# iteration started for: b
# b
# iteration ended for: b
# iteration started for: c
# c
# iteration ended for: c
# iteration started for: d
# d
# iteration ended for: d
# othere statements in program
# program ended

# %%
# while for=
print "program started"
s=raw_input("Enter a value:")
for i in s:
    print "iteration started for: %s"%i
    if i==" ":
        print "<SPACE>"
        break
    else:
        print i
    print "iteration ended for: %s"%i
    
print "othere statements in program"
print "program ended"
# Out:
# program started
# Enter a value:ab c
# iteration started for: a
# a
# iteration ended for: a
# iteration started for: b
# b
# iteration ended for: b
# iteration started for:
# <SPACE>
# othere statements in program
# program ended

# %%
# while for=
print "program started"
s=raw_input("Enter a value:")
for i in s:
    print "iteration started for: %s"%i
    if i==" ":
        print "<SPACE>"
        break
    else:
        print i
    print "iteration ended for: %s"%i
else:
    print "This is else: executing beacuse completed all the iterations"
    
print "othere statements in program"
print "program ended"
# Out:
# program started
# Enter a value:abcd
# iteration started for: a
# a
# iteration ended for: a
# iteration started for: b
# b
# iteration ended for: b
# iteration started for: c
# c
# iteration ended for: c
# iteration started for: d
# d
# iteration ended for: d
# This is else: executing beacuse completed all the iterations
# othere statements in program
# program ended

# %%
# while for=
print "program started"
s=raw_input("Enter a value:")
for i in s:
    print "iteration started for: %s"%i
    if i==" ":
        print "<SPACE>"
        break
    else:
        print i
    print "iteration ended for: %s"%i
else:
    print "This is else: executing beacuse completed all the iterations"
    
print "othere statements in program"
print "program ended"
# Out:
# program started
# Enter a value:a b c d
# iteration started for: a
# a
# iteration ended for: a
# iteration started for:
# <SPACE>
# othere statements in program
# program ended

# %%
# while for=
print "program started"
s=raw_input("Enter a value:")
for i in s:
    print "iteration started for: %s"%i
    print i
    print "iteration ended for: %s"%i
else:
    print "This is else: executing beacuse completed all the iterations"
    
print "othere statements in program"
print "program ended"
# Out:
# program started
# Enter a value:abcd
# iteration started for: a
# a
# iteration ended for: a
# iteration started for: b
# b
# iteration ended for: b
# iteration started for: c
# c
# iteration ended for: c
# iteration started for: d
# d
# iteration ended for: d
# This is else: executing beacuse completed all the iterations
# othere statements in program
# program ended

# %%
# while for=
print "program started"
s=raw_input("Enter a value:")
for i in s:
    print "iteration started for: %s"%i
    if i==" ":
        continue
    else:
        print i
    print "iteration ended for: %s"%i
else:
    print "This is else: executing beacuse completed all the iterations"
    
print "othere statements in program"
print "program ended"
# Out:
# program started
# Enter a value:a b c d
# iteration started for: a
# a
# iteration ended for: a
# iteration started for:
# iteration started for: b
# b
# iteration ended for: b
# iteration started for:
# iteration started for: c
# c
# iteration ended for: c
# iteration started for:
# iteration started for: d
# d
# iteration ended for: d
# This is else: executing beacuse completed all the iterations
# othere statements in program
# program ended

# %%
# while for=
print "program started"
s=raw_input("Enter a value:")
for i in s:
    print "iteration started for: %s"%i
    if i==" ":
        pass
    else:
        print i
    print "iteration ended for: %s"%i
else:
    print "This is else: executing beacuse completed all the iterations"
    
print "othere statements in program"
print "program ended"
# Out:
# program started
# Enter a value:a b c d
# iteration started for: a
# a
# iteration ended for: a
# iteration started for:
# iteration ended for:
# iteration started for: b
# b
# iteration ended for: b
# iteration started for:
# iteration ended for:
# iteration started for: c
# c
# iteration ended for: c
# iteration started for:
# iteration ended for:
# iteration started for: d
# d
# iteration ended for: d
# This is else: executing beacuse completed all the iterations
# othere statements in program
# program ended

# %%
# while for=
print "program started"
s=raw_input("Enter a value:")
for i in s:
    print "iteration started for: %s"%i
    if i==" ":
        continue
    else:
        print i
    print "other statements in loop"
    print "some statements in loop"
    print "iteration ended for: %s"%i
    
else:
    print "This is else: executing beacuse completed all the iterations"
    
print "othere statements in program"
print "program ended"
# Out:
# program started
# Enter a value:ab cd
# iteration started for: a
# a
# other statements in loop
# some statements in loop
# iteration ended for: a
# iteration started for: b
# b
# other statements in loop
# some statements in loop
# iteration ended for: b
# iteration started for:
# iteration started for: c
# c
# other statements in loop
# some statements in loop
# iteration ended for: c
# iteration started for: d
# d
# other statements in loop
# some statements in loop
# iteration ended for: d
# This is else: executing beacuse completed all the iterations
# othere statements in program
# program ended

# %%
i=0
while i<10:
    break
    i=i+1
print "i outside:",i
# Out:
# i outside: 0

# %%
i=0
while i<10:
    i=i+1
    break
print "i outside:",i
# Out:
# i outside: 1

# %%
i=0
while i<10:
    i=i+1
    continue
print "i outside:",i

# %%
i=0
while i<10:
    continue
    i=i+1
print "i outside:",i

# %%
i=0
while i<10:
    i=i-1
print "i outside:",i

# %%
for i in "":
    print i
print "i out side loop:",i

# %%
for i in "python":
    print i
print "i out side loop:",i

# %%
for i in "python":
    print i
    break
print "i out side loop:",i

# %%
for i in "python":
    continue
    print i
print "i out side loop:",i
